# %% [markdown]
# ## Evaluation Framework
#
# We designed a custom evaluation pipeline to assess our generative models on multiple quality dimensions, combining semantic, stylistic, and structural criteria. The evaluation runs on four core queries and reports aggregate metrics across all responses. Here's how it works:
#
# ### 1. Corpus Setup + Embedding Style Vector
# We first load our cleaned Einstein corpus and randomly select up to 200 passages. Using the `all-MiniLM-L6-v2` encoder, we embed each passage and compute the average embedding across the sample. This gives us a reference “style vector” representing the general tone and semantics of Einstein’s writing. Later, we use this vector to compute how stylistically aligned a generated answer is.
#
# ### 2. Query-Based Evaluation
# We define four standard queries that probe conceptual and scientific themes in Einstein’s thought. For each query, we generate a response using the provided model function and record various linguistic and semantic properties.
#
# ### 3. Style & Relevance Metrics
# - **StyleSim**: Cosine similarity between the answer’s embedding and the precomputed Einstein style vector. High values indicate stylistic alignment with the corpus.
# - **QuerySim**: Cosine similarity between the query embedding and the response embedding, measuring how semantically relevant the answer is.
# - **Repetition**: Using TF-IDF cosine similarity, we compare all sentence pairs in the answer. High values mean redundant phrasing, which we penalize.
#
# ### 4. Fluency & Diversity Metrics
# - **Tokens**: Total number of words in the response
# - **LexDiv**: Lexical diversity — unique words over total words
# - **Distinct-1 / Distinct-2**: Measures how often unigrams and bigrams are repeated
# - **AvgSentLen**: Average number of words per sentence — a proxy for sentence complexity
#
# ### 5. Timing
# - **GenTime(s)**: Time in seconds to generate each response — useful for comparing model speed
#
# The final output is a `pandas` DataFrame with per-query metrics and a summary of average values. This lets us compare different models not just by performance or plausibility, but also by elegance, precision, and stylistic authenticity.

# %%
import numpy as np
import pandas as pd
import time
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import NearestNeighbors

# Define evaluation queries
queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the relationship between gravity and acceleration?",
    "How does mass affect space-time?"
]

# Load cleaned Einstein corpus and compute mean style embedding
CLEANED_PATH = '/Users/francescoiaccarino/Desktop/Università/DSBA/2nd semester/NLP/nlp_proj/txts/ciccio/bohr_cleaned_text.csv'
with open(CLEANED_PATH, 'r', encoding='utf-8') as f:
    lines = [l.strip() for l in f if l.strip()]

# Initialize embedder and compute mean embedding of a random sample of passages
embedder = SentenceTransformer("all-MiniLM-L6-v2")
sample = np.random.choice(lines, min(len(lines), 200), replace=False)
mean_emb = embedder.encode(sample.tolist(), convert_to_numpy=True).mean(axis=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Auxiliary function to compute internal repetition score
def repetition_score(text):
    sentences = [s.strip() for s in text.split('.') if len(s.strip().split()) > 3]
    if len(sentences) < 2:
        return 0.0
    tfidf = TfidfVectorizer().fit_transform(sentences)
    sim_matrix = cosine_similarity(tfidf)
    n = len(sentences)
    repetition = (sim_matrix.sum() - n) / (n * (n - 1))
    return repetition

# Main evaluation function
def evaluate_model_metrics(model_fn, model_name="CustomModel", verbose=False):
    """
    Evaluate textual quality and semantic relevance of a generative model.

    Args:
        model_fn (function): A function that takes a query string and returns a generated response.
        model_name (str): Optional name for the model (used in output).
        verbose (bool): If True, prints each query and generated response.

    Returns:
        dict: Dictionary of average evaluation metrics.
    """
    records = []

    for query in queries:
        start = time.time()
        response = model_fn(query)
        if response is None:
            print(f"[ERROR] No valid response for query: {query}")
            continue

        gen_time = time.time() - start

        if verbose:
            print(f"\n[Query] {query}\n[Response] {response}\n")

        tokens = response.split()
        length = len(tokens)
        lex_div = len(set(tokens)) / length if length else 0
        bigrams = list(zip(tokens, tokens[1:]))
        distinct1 = len(set(tokens)) / length if length else 0
        distinct2 = len(set(bigrams)) / len(bigrams) if bigrams else 0
        sentences = [s.strip() for s in response.split('.') if s.strip()]
        sent_lens = [len(s.split()) for s in sentences]
        avg_sent_len = np.mean(sent_lens) if sent_lens else 0

        # Style similarity to Einstein corpus
        resp_emb = embedder.encode([response], convert_to_numpy=True)[0]
        style_sim = float(np.dot(resp_emb, mean_emb) / (np.linalg.norm(resp_emb) * np.linalg.norm(mean_emb)))

        # Semantic relevance (query-to-response similarity)
        query_emb = embedder.encode([query], convert_to_numpy=True)[0]
        query_sim = float(np.dot(query_emb, resp_emb) / (np.linalg.norm(query_emb) * np.linalg.norm(resp_emb)))

        # Internal repetition
        repetition = repetition_score(response)

        records.append({
            "Query": query,
            "Tokens": length,
            "LexDiv": lex_div,
            "Distinct-1": distinct1,
            "Distinct-2": distinct2,
            "AvgSentLen": avg_sent_len,
            "StyleSim": style_sim,
            "QuerySim": query_sim,
            "Repetition": repetition,
            "GenTime(s)": round(gen_time, 3)
        })

    df = pd.DataFrame(records)
    metric_cols = ["Tokens", "LexDiv", "Distinct-1", "Distinct-2", "AvgSentLen",
                   "StyleSim", "QuerySim", "Repetition", "GenTime(s)"]
    summary = df[metric_cols].mean().to_dict()

    print(f"\n=== Metrics for {model_name} ===")
    for metric, value in summary.items():
        print(f"{metric}: {value:.4f}")

    return summary

# %% [markdown]
# The baseline is a generator which is trained just on its own parameters and not referring to files that, in other models, we retrieve, so the baseline answers out of its own pretraining.

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-macosx_14_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 61.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
import pandas as pd
import numpy as np
import time
import random
from IPython.display import display
from sentence_transformers import SentenceTransformer
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import faiss

# Load FAISS index
print("[EVAL] Building FAISS index...")
passage_embeddings = embedder.encode(lines, convert_to_numpy=True, show_progress_bar=True)
index = faiss.IndexFlatL2(passage_embeddings.shape[1])
index.add(passage_embeddings)
print("[EVAL] FAISS index ready.")

baseline_tokenizer = AutoTokenizer.from_pretrained("gpt2")
baseline_model     = AutoModelForCausalLM.from_pretrained("gpt2")
baseline_pipe      = pipeline(
    "text-generation",
    model=baseline_model,
    tokenizer=baseline_tokenizer,
    device=-1
)

def baseline_chatbot(prompt: str, max_new_tokens: int = 50):
    full = f"You are a helpful assistant. Answer succinctly:\n\nQuestion: {prompt}\nAnswer:"
    out = baseline_pipe(
        full,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=0.9,
        temperature=0.8,
        pad_token_id=baseline_tokenizer.eos_token_id
    )[0]["generated_text"]
    return out.split("Answer:")[-1].strip()


evaluate_model_metrics(baseline_chatbot, model_name="BASELINE", verbose=True)
# Out:
# [EVAL] Building FAISS index...
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# [EVAL] FAISS index ready.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %% [markdown]
# # MODEL 1: RAG
#
# We’ve built a simple Retrieval-Augmented Generation (RAG) system in six stages to combine information lookup with language generation:
#
# 1) **Loading the Cleaned Corpus**
# We read our preprocessed Einstein paragraphs from disk into a list called `passages`, skipping empty lines.
#
# 2) **Embedding with SentenceTransformer**
# We initialize the `all-MiniLM-L6-v2` SentenceTransformer, which maps any sentence or paragraph into a 384-dimensional real vector. We compute embeddings in batches to avoid memory issues, and then stack them into a single NumPy array called `passage_embeddings`. We deliberately chose this specific model because it’s lightweight, fast, and surprisingly accurate even without a GPU—ideal for encoding thousands of passages quickly and comparing them semantically to new questions.
#
# 3) **Indexing with FAISS**
# We feed all paragraph embeddings into FAISS (`IndexFlatL2`), a library optimized for fast nearest-neighbor search. This lets us retrieve the most semantically similar chunks to a given question using simple Euclidean distance, in just milliseconds, even on CPU.
#
# 4) **Preparing the Generator**
# We use the base GPT-2 model (`gpt2`) as our text generator via HuggingFace’s `pipeline`. Even though GPT-2 isn’t instruction-tuned, it still generates coherent English and can synthesize retrieved content when guided with the right prompt.
#
# 5) **Retrieval + Generation (`rag_answer`)**
# Given a question, we embed the query, retrieve the top-k most relevant paragraphs, and concatenate them with an instruction prompt like “You are Albert Einstein. Paraphrase and synthesize the ideas…” followed by the user’s question. This full prompt is sent to GPT-2, which generates up to 200 new tokens as the answer. We also print out the retrieved chunks and their distances for debugging purposes.
#
# 6) **Silent Version (`rag_answer_silent`)**
# This alternative version hides all the print statements and returns only the cleaned answer string, extracted after the “Answer:” marker. It’s useful for automatic evaluation or frontend integration. We also added a small postprocessing step to remove anything trailing after a newline or unintended repeat prompts.

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
import os
import time
from sentence_transformers import SentenceTransformer
import faiss
from transformers import pipeline

corpus_path = "einstein_cleaned_final.txt"
print(f"[1/6] Loading corpus from {corpus_path}...")
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/6] Done. {len(passages)} passages loaded.\n")

print("[2/6] Initializing SentenceTransformer embedder...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/6] Embedder ready.\n")

batch_size = 64
all_embeddings = []
print("[3/6] Computing embeddings in batches:")
start_time = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    all_embeddings.append(embs)
    print(f"    • Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} done", flush=True)
passage_embeddings = __import__('numpy').vstack(all_embeddings)
elapsed = time.time() - start_time
print(f"[3/6] Embeddings computed: shape={passage_embeddings.shape}, time={elapsed:.1f}s\n")

dim = passage_embeddings.shape[1]
print("[4/6] Building FAISS index (IndexFlatL2)...", flush=True)
index = faiss.IndexFlatL2(dim)
start_time = time.time()
index.add(passage_embeddings)
elapsed = time.time() - start_time
print(f"[4/6] FAISS index built: {index.ntotal} vectors indexed in {elapsed:.2f}s\n", flush=True)

print("[5/6] Initializing text-generation pipeline (GPT-2)...", flush=True)
generator = pipeline('text-generation', model='gpt2', tokenizer='gpt2')
print("[5/6] Generator ready.\n", flush=True)

def rag_answer(query, k=3):
    print(f"[6] Retrieving top {k} passages for query: {query!r}", flush=True)
    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)
    ctx = [passages[i] for i in I[0]]
    for rank, (dist, text) in enumerate(zip(D[0], ctx), 1):
        print(f"    {rank}. (dist={dist:.3f}) {text[:60]}…", flush=True)

    prompt = (
        "You are Albert Einstein. Paraphrase and synthesize the ideas below in your own words, "
        "avoiding verbatim quotes. Then answer:\n\n"
        + "\n---\n".join(ctx)
        + f"\n\nQuestion: {query}\nAnswer:"
    )
    out = generator(prompt, max_new_tokens=200, do_sample=True, early_stopping=True, top_p=0.9)[0]['generated_text']
    print("[6] Generation complete.\n", flush=True)
    return out

def rag_answer_silent(query, k=3, max_new_tokens=200, top_p=0.8):
    q_emb = embedder.encode([query], convert_to_numpy=True)
    _, I = index.search(q_emb, k)
    context = [passages[i] for i in I[0]]

    prompt = (
        "You are Albert Einstein. Based on the following notes, answer the question simply and clearly:\n\n"
        + "\n---\n".join(context)
        + f"\n\nQuestion: {query}\nAnswer:"
    )

    generated_output = generator(
        prompt,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        temperature=0.7,
        top_p=top_p,
        repetition_penalty=1.2,
        pad_token_id=generator.tokenizer.eos_token_id
    )[0]['generated_text']

    # Extract only the part after 'Answer:' and stop at first break or repeated marker
    answer = generated_output.split("Answer:")[-1].strip()
    for stop_token in ["\n\n", "Question:", "Answer:"]:
        if stop_token in answer:
            answer = answer.split(stop_token)[0].strip()
    return answer

'''
queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the nature of light?"
]

for q in queries:
    print("=== QUERY ===")
    print(q)
    answer_verbose = rag_answer(q, k=3)
    answer_silent = rag_answer_silent(q, k=3)
    print("=== ANSWER (verbose) ===")
    print(answer_verbose)
    print("=== ANSWER (silent) ===")
    print(answer_silent)
    print("\n")
'''
# Out:
# [1/6] Loading corpus from einstein_cleaned_final.txt...
# [1/6] Done. 3216 passages loaded.
#
# [2/6] Initializing SentenceTransformer embedder...
# [2/6] Embedder ready.
#
# [3/6] Computing embeddings in batches:
#     • Batch 1/51 done
#     • Batch 2/51 done
#     • Batch 3/51 done
#     • Batch 4/51 done
#     • Batch 5/51 done
#     • Batch 6/51 done
#     • Batch 7/51 done
#     • Batch 8/51 done
#     • Batch 9/51 done
#     • Batch 10/51 done
#     • Batch 11/51 done
#     • Batch 12/51 done
#     • Batch 13/51 done
#     • Batch 14/51 done
#     • Batch 15/51 done
#     • Batch 16/51 done
#     • Batch 17/51 done
#     • Batch 18/51 done
#     • Batch 19/51 done
#     • Batch 20/51 done
#     • Batch 21/51 done
#     • Batch 22/51 done
#     • Batch 23/51 done
#     • Batch 24/51 done
#     • Batch 25/51 done
#     • Batch 26/51 done
#     • Batch 27/51 done
#     • Batch 28/51 done
#     • Batch 29/51 done
#     • Batch 30/51 done
#     • Batch 31/51 done
#     • Batch 32/51 done
#     • Batch 33/51 done
#     • Batch 34/51 done
#     • Batch 35/51 done
#     • Batch 36/51 done
#     • Batch 37/51 done
#     • Batch 38/51 done
#     • Batch 39/51 done
#     • Batch 40/51 done
#     • Batch 41/51 done
#     • Batch 42/51 done
#     • Batch 43/51 done
#     • Batch 44/51 done
#     • Batch 45/51 done
#     • Batch 46/51 done
#     • Batch 47/51 done
#     • Batch 48/51 done
#     • Batch 49/51 done
#     • Batch 50/51 done
#     • Batch 51/51 done
# [3/6] Embeddings computed: shape=(3216, 384), time=7.1s
#
# [4/6] Building FAISS index (IndexFlatL2)...
# [4/6] FAISS index built: 3216 vectors indexed in 0.00s
#
# [5/6] Initializing text-generation pipeline (GPT-2)...
# Device set to use cuda:0
# [5/6] Generator ready.
# '\nqueries = [\n    "What is the nature of time?",\n    "How would you describe imagination?",\n    "What is the nature of light?"\n]\n\nfor q in queries:\n    print("=== QUERY ===")\n    print(q)\n    answer_verbose = rag_answer(q, k=3)\n    answer_silent = rag_answer_silent(q, k=3)\n    print("=== ANSWER (verbose) ===")\n    print(answer_verbose)\n    print("=== ANSWER (silent) ===")\n    print(answer_silent)\n    print("\n")\n'

# %%
evaluate_model_metrics(rag_answer_silent, model_name="RAG", verbose=True)
# Out:
# [Query] What is the nature of time?
# [Response] We may say we know nothing about its development since there exists only two definite facts; namely, each has been known before us through experience ; but they differ very little between those who consider them merely hypotheses concerning their properties — i.-v., "what happens during" etc. This difference arises out almost completely upon considering things other than themselves : while either hypothesis might seem more probable after having taken into consideration both phenomena independently, yet because neither could ever take up enough weight within itself against further considerations I should like you heretofore considered my present argumentation. For whatever follows must follow naturally until proven true! And though sometimes 'the same thing' occurs again & still differs frequently over many years ^^ As far away does your mind go? You do understand something depends how much light comes down under certain conditions even among people whose minds remain always open till later times where sunlight passes along... In short...I am convinced -- although now too late -that unless somebody really knows everything **about Time/
#
#
# [Query] How would you describe imagination?
# [Response] The only difference from what I have said above lies within my own personal definition : namely, It can exist without being subject to any physical form! In reality both mind & body cannot ever change shape because they do nothing else except alter themselves through some very specific process - either one must find another way before something changes into existence again after having had time enough alone during these cycles where two different kinds thereof arise simultaneously
#
#
# [Query] What is the relationship between gravity and acceleration?
# [Response] Gravity depends upon being stationary at some distance along space as well ; hence we have also said here about inertia. But when given such principles they can hardly possibly prove true without proving certain other things too — namely, whether magnetism may act independently according thereto? And then how should relativists proceed against those who say no laws will ever hold up under actual conditions! In short what follows gives me reason enough to reject them altogether! So long you ask my dear friend Dr. Lüningen Jörgleau's statement above concerning G2^4 -energy alone only makes clear why he would think otherwise than after having tried everything out before him himself!! He did indeed explain away several problems regarding physical theory just now but still didn't get rid entirely old ideas into use until quite recently!!! Now let� s talk again together firstly because Mr.-Luther says very little except perhaps ''that 'the real world' cannot bear constant change''". If anything like science had existed during D
#
#
# [Query] How does mass affect space-time?
# [Response] The fact that there exists no continuous time or change will have consequences beyond our control ; however this could certainly happen without any changes affecting all phenomena at once — just what happens when one person says "I am going back through history"? If you want to see how many people were killed during World War II, look closely around your house! Even before war did begin? That would seem like something outmoded. But after wars do things get really interesting again! We live under military dictatorships because they create these laws so easily now!! A dictator might say ''There should be five hundred thousand men here today who don't know about atomic bombs.'' Now he knows nothing anymore even though some experts believe him right away ^^ And those four words alone make his life miserable!! One day every ten years someone else takes over their country too... They need two million soldiers instead... So maybe somebody needs six millions plus.... There must be somewhere within us where everything goes wrong except between 1/3rds."
#
#
# === Metrics for RAG ===
# Tokens: 149.0000
# LexDiv: 0.9986
# Distinct-1: 0.9986
# Distinct-2: 1.0000
# AvgSentLen: 40.8143
# StyleSim: 0.4140
# QuerySim: 0.2669
# Repetition: 0.0048
# GenTime(s): 1.7550
# {'Tokens': 149.0,
#  'LexDiv': 0.9985795454545454,
#  'Distinct-1': 0.9985795454545454,
#  'Distinct-2': 1.0,
#  'AvgSentLen': 40.81428571428571,
#  'StyleSim': 0.41397859901189804,
#  'QuerySim': 0.26694064028561115,
#  'Repetition': 0.004791567853423769,
#  'GenTime(s)': 1.7550000000000003}

# %% [markdown]
# # MODEL 2: GPT-2 Large RAG Pipeline
#
# This model builds upon our first RAG system, but introduces some important upgrades—most notably a stronger language model (GPT-2 Large) and a more refined prompting strategy for better, more focused responses.
#
# 1) **Loading the Cleaned Corpus**
# Just like before, we load our cleaned Einstein corpus into a list of passages. Each passage is a self-contained snippet of text.
#
# 2) **Embedding with SentenceTransformer**
# We continue using `all-MiniLM-L6-v2` to embed the corpus into 384-dimensional vectors. This SentenceTransformer strikes the best balance between speed and semantic quality, especially on CPU.
#
# 3) **Indexing with FAISS**
# Again, we rely on FAISS’s `IndexFlatL2` to efficiently retrieve the top-k most semantically similar passages to any given query, based on L2 distance.
#
# 4) **Upgrading the Generator: GPT-2 → GPT-2 Large**
# Here’s the first major change: we switch from regular `gpt2` to the much more powerful `gpt2-large`. GPT-2 Large has significantly more parameters (774M vs. 124M), which allows it to generate much more coherent and nuanced responses. To make use of the model effectively, we also run it on GPU (`device=0`).
#
# 5) **Refined Prompting Strategy**
# Instead of a general “paraphrase and synthesize” prompt, we now use a much more precise instruction: Einstein is imagined answering a curious student in a clear, concise, and complete way—limited to 2-3 sentences. The prompt discourages vague or meta-style outputs and explicitly asks for a self-contained, final answer. This helps constrain GPT-2 Large to generate focused replies.
#
# 6) **Trimming the Output for Clarity**
# We extract the generated text and limit the final answer to the first 2-3 complete sentences, which avoids overly long or rambling outputs. We also do light postprocessing to clean up formatting and trailing punctuation.
#
# **Key Differences from Model 1:**
# - **Stronger Generator:** GPT-2 Large replaces GPT-2 for better fluency and reasoning.
# - **Sharper Prompting:** More detailed, instructional prompt tailored to concise and educational answers.
# - **Postprocessing:** Automatic trimming to 2-3 sentences for consistency across outputs.
# - **GPU Usage:** The pipeline is explicitly set to run on GPU for faster generation.
#
# Overall, this model delivers noticeably sharper and more polished responses, making it a strong baseline for generating grounded, Einstein-style answers.

# %%
import os
import time
from sentence_transformers import SentenceTransformer
import faiss
from transformers import pipeline
import numpy as np

# Step 1: Load the cleaned corpus
corpus_path = 'einstein_cleaned_final.txt'
print(f"[1/6] Loading corpus from {corpus_path}...")
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/6] Done. {len(passages)} passages loaded.\n")

# Step 2: Initialize the embedding model
print("[2/6] Initializing SentenceTransformer embedder...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/6] Embedder ready.\n")

# Step 3: Compute and stack passage embeddings
batch_size = 64
all_embeddings = []
print("[3/6] Computing embeddings in batches:")
start_time = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    all_embeddings.append(embs)
    print(f"    • Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} done", flush=True)

passage_embeddings = np.vstack(all_embeddings)
elapsed = time.time() - start_time
print(f"[3/6] Embeddings computed: shape={passage_embeddings.shape}, time={elapsed:.1f}s\n")

# Step 4: Build FAISS index for similarity search
dim = passage_embeddings.shape[1]
print("[4/6] Building FAISS index (IndexFlatL2)...", flush=True)
index = faiss.IndexFlatL2(dim)
start_time = time.time()
index.add(passage_embeddings)
elapsed = time.time() - start_time
print(f"[4/6] FAISS index built: {index.ntotal} vectors indexed in {elapsed:.2f}s\n", flush=True)

# Step 5: Load GPT-2 Large as the text generator
print("[5/6] Initializing text-generation pipeline (GPT-2 Large)...", flush=True)
generator = pipeline(
    "text-generation",
    model="gpt2-large",
    tokenizer="gpt2-large",
    device=0
)
print("[5/6] Generator ready.\n", flush=True)

# Step 6: Define the RAG-style answer generation function
def gpt_2_answer(query, k=3):
    print(f"[6] Retrieving top {k} passages for query: {query!r}", flush=True)
    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)
    context = [passages[i][:300] for i in I[0]]

    for rank, (dist, text) in enumerate(zip(D[0], context), 1):
        print(f"    {rank}. (dist={dist:.3f}) {text[:60]}…", flush=True)

    prompt = (
        "Albert Einstein is asked a scientific question by a curious student. "
        "Using only the notes below, he gives a clear, concise, and complete answer in 2 to 3 sentences. "
        "He avoids lists, vague generalities, and meta-comments. The answer is final and self-contained.\n\n"
        + "\n---\n".join(context)
        + f"\n\nQuestion: {query}\nAnswer:"
    )

    output = generator(
        prompt,
        max_new_tokens=120,
        temperature=0.45,
        top_p=0.72,
        repetition_penalty=1.5,
        do_sample=True,
        pad_token_id=generator.tokenizer.eos_token_id,
        eos_token_id=generator.tokenizer.eos_token_id,
        return_full_text=False
    )[0]['generated_text']

    # Extract and truncate the output to the first 2–3 complete sentences
    answer = output.strip()
    sentence_split = answer.replace('\n', ' ').split('. ')
    if len(sentence_split) >= 3:
        answer = '. '.join(sentence_split[:3]).strip()
    elif len(sentence_split) >= 2:
        answer = '. '.join(sentence_split[:2]).strip()
    else:
        answer = sentence_split[0].strip()

    if not answer.endswith('.'):
        answer += '.'

    while answer[-1] in [':', ';']:
        answer = answer[:-1].strip() + '.'

    print("[6] Generation complete.\n")
    return answer

# Example usage:
'''
queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the nature of light?"
]

for q in queries:
    print("=== QUERY ===")
    print(q)
    answer = gpt_2_answer(q, k=3)
    print("=== ANSWER ===")
    print(answer)
    print("\n")
'''
# Out:
# [1/6] Loading corpus from einstein_cleaned_final.txt...
# [1/6] Done. 3216 passages loaded.
#
# [2/6] Initializing SentenceTransformer embedder...
# [2/6] Embedder ready.
#
# [3/6] Computing embeddings in batches:
#     • Batch 1/51 done
#     • Batch 2/51 done
#     • Batch 3/51 done
#     • Batch 4/51 done
#     • Batch 5/51 done
#     • Batch 6/51 done
#     • Batch 7/51 done
#     • Batch 8/51 done
#     • Batch 9/51 done
#     • Batch 10/51 done
#     • Batch 11/51 done
#     • Batch 12/51 done
#     • Batch 13/51 done
#     • Batch 14/51 done
#     • Batch 15/51 done
#     • Batch 16/51 done
#     • Batch 17/51 done
#     • Batch 18/51 done
#     • Batch 19/51 done
#     • Batch 20/51 done
#     • Batch 21/51 done
#     • Batch 22/51 done
#     • Batch 23/51 done
#     • Batch 24/51 done
#     • Batch 25/51 done
#     • Batch 26/51 done
#     • Batch 27/51 done
#     • Batch 28/51 done
#     • Batch 29/51 done
#     • Batch 30/51 done
#     • Batch 31/51 done
#     • Batch 32/51 done
#     • Batch 33/51 done
#     • Batch 34/51 done
#     • Batch 35/51 done
#     • Batch 36/51 done
#     • Batch 37/51 done
#     • Batch 38/51 done
#     • Batch 39/51 done
#     • Batch 40/51 done
#     • Batch 41/51 done
#     • Batch 42/51 done
#     • Batch 43/51 done
#     • Batch 44/51 done
#     • Batch 45/51 done
#     • Batch 46/51 done
#     • Batch 47/51 done
#     • Batch 48/51 done
#     • Batch 49/51 done
#     • Batch 50/51 done
#     • Batch 51/51 done
# [3/6] Embeddings computed: shape=(3216, 384), time=7.2s
#
# [4/6] Building FAISS index (IndexFlatL2)...
# [4/6] FAISS index built: 3216 vectors indexed in 0.00s
#
# [5/6] Initializing text-generation pipeline (GPT-2 Large)...
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# [5/6] Generator ready.
# '\nqueries = [\n    "What is the nature of time?",\n    "How would you describe imagination?",\n    "What is the nature of light?"\n]\n\nfor q in queries:\n    print("=== QUERY ===")\n    print(q)\n    answer = gpt_2_answer(q, k=3)\n    print("=== ANSWER ===")\n    print(answer)\n    print("\n")\n'

# %%
evaluate_model_metrics(gpt_2_answer, model_name="GPT2", verbose=True)
# Out:
# [6] Retrieving top 3 passages for query: 'What is the nature of time?'
#     1. (dist=0.771) The time of an event taking place at a point P( x, y, z) is …
#     2. (dist=0.787) But thus withdrawn for long periods from the will-hardening …
#     3. (dist=0.858) It is hardly necessary to add, that anything which any insul…
# [6] Generation complete.
#
#
# [Query] What is the nature of time?
# [Response] Time consists simply in its relation to matter; but this does not mean that there are no other relations between them than those we have already considered — namely, their mutual action upon each other through change. It may also occur (as I think most likely), that these two forces act together more powerfully when one object has been produced than when both objects exist independently. For instance, if you put your hand into water while holding onto something else, the force acting against your hand would probably outweigh the force acting against the thing held.
#
# [6] Retrieving top 3 passages for query: 'How would you describe imagination?'
#     1. (dist=1.121) Il we ask ourselves how the structure of society and the cul…
#     2. (dist=1.162) For it to blossom there is needed, first of all, a certain d…
#     3. (dist=1.171) These no tion of such a setting rests exclusively on the fac…
# [6] Generation complete.
#
#
# [Query] How would you describe imagination?
# [Response] It consists in an active participation with other people's ideas or thoughts, so far as they have been developed from experience (and sometimes also when these were derived). This activity may take place without any direct contact with reality — as if one had imagined something else entirely—or through close association with real objects, especially those whose existence has already become known to oneself. In either case it must always remain open to change, because every new idea brings about changes in its own nature.
#
# [6] Retrieving top 3 passages for query: 'What is the relationship between gravity and acceleration?'
#     1. (dist=0.965) The nature of acceleration of an infinitely small (posi- tio…
#     2. (dist=0.967) This acceleration or curvature corresponds to the influence …
#     3. (dist=1.071) More pedantically a physicist formulates the same conclusion…
# [6] Generation complete.
#
#
# [Query] What is the relationship between gravity and acceleration?
# [Response] In order to understand what we mean when we say "gravity," it will help if one understands how gravitation works at all levels of description from elementary particles through quantum mechanics. We shall use Newton's second law as a starting point ; however, since there have been many changes over time, some modifications may need to occur before any meaningful understanding can take place. For example, consider two objects whose masses differ but who share certain properties such as position, momentum, angular velocity, etc., i.e., they both exhibit motion along their axes.
#
# [6] Retrieving top 3 passages for query: 'How does mass affect space-time?'
#     1. (dist=0.963) (2) From very accurate experi- ments (specially from the tor…
#     2. (dist=1.015) Masses which are sufficiently far from each other and from o…
#     3. (dist=1.027) This theory has not yet caught the popular imagination to th…
# [6] Generation complete.
#
#
# [Query] How does mass affect space-time?
# [Response] Mass affects both space- time and gravity; for example, if one were able to measure the masses of all particles at any instant in spacetime, they would be found to have an effect on their motion relative to each other. In this way, there could exist many different kinds of "mass" — some more massive than others. For instance, if you had two identical objects weighing 100 kilograms each, they will move towards each other because they share similar properties.
#
#
# === Metrics for GPT2 ===
# Tokens: 88.2500
# LexDiv: 0.9266
# Distinct-1: 0.9266
# Distinct-2: 0.9895
# AvgSentLen: 25.7083
# StyleSim: 0.3102
# QuerySim: 0.6082
# Repetition: 0.0377
# GenTime(s): 3.9445
# {'Tokens': 88.25,
#  'LexDiv': 0.9266211104006821,
#  'Distinct-1': 0.9266211104006821,
#  'Distinct-2': 0.9894736842105263,
#  'AvgSentLen': 25.708333333333332,
#  'StyleSim': 0.31015417352318764,
#  'QuerySim': 0.608165442943573,
#  'Repetition': 0.037726012968007386,
#  'GenTime(s)': 3.9445}

# %% [markdown]
# # MODEL 3: GPT-2 Large with Advanced Prompting
#
# In this third model, we build on the previous GPT-2 Large RAG system by introducing a more polished prompting strategy and better output control, aiming for answers that are not just relevant, but stylistically clear, final, and self-contained.
#
# 1) **Loading the Cleaned Corpus**
# As with previous models, we load our cleaned Einstein corpus into memory, storing each paragraph as a separate entry in a list called `passages`.
#
# 2) **Embedding with SentenceTransformer**
# We continue to use `all-MiniLM-L6-v2` for computing 384-dimensional semantic embeddings of each passage. The model is lightweight yet accurate enough to retrieve relevant chunks from our corpus efficiently, even without a GPU.
#
# 3) **Indexing with FAISS**
# We index all passage embeddings using FAISS (`IndexFlatL2`) to enable fast similarity search. This step remains unchanged from previous models.
#
# 4) **Generator: GPT-2 Large**
# We again use `gpt2-large` as the generator, running it on GPU for speed. The model's large size allows it to generate more coherent and meaningful responses than the base GPT-2.
#
# 5) **Prompt Formatting Upgrade**
# This is the core improvement of this model. We define a dedicated `format_prompt()` function to construct consistent, high-quality prompts. The new prompt emphasizes natural, self-contained language and instructs the model to avoid vague generalities or references to external information. The idea is to simulate how Einstein would respond thoughtfully and clearly to a curious question using only the retrieved notes.
#
# 6) **Cleaner Answer Extraction**
# We improve post-processing by cleaning the generated output to extract just the answer portion (after “Answer:”), trimming any trailing artifacts or prompt echoes. We also truncate the text after the last full sentence to ensure brevity and clarity.
#
# **Key Differences from Model 2:**
# - **Dedicated prompt formatter** to ensure consistent tone and structure across queries.
# - **Better answer cleanup**: more robust text extraction and trimming logic.
# - **Tighter sampling controls**: slightly lower temperature and higher repetition penalty for more focused responses.
#
# This model represents our most refined setup so far, blending strong retrieval, a powerful generator, and a well-crafted prompt to produce high-quality Einstein-style answers.

# %%
import os
import time
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from transformers import pipeline

# Step 1: Load the preprocessed Einstein corpus
corpus_path = 'einstein_cleaned_final.txt'
print(f"[1/6] Loading corpus from {corpus_path}...")
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/6] Done. {len(passages)} passages loaded.\n")

# Step 2: Initialize the sentence embedder
print("[2/6] Initializing SentenceTransformer embedder...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/6] Embedder ready.\n")

# Step 3: Compute and stack embeddings for all passages
batch_size = 64
all_embeddings = []
print("[3/6] Computing embeddings in batches:")
start_time = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    all_embeddings.append(embs)
    print(f"    • Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} done", flush=True)
passage_embeddings = np.vstack(all_embeddings)
elapsed = time.time() - start_time
print(f"[3/6] Embeddings ready (shape={passage_embeddings.shape}) in {elapsed:.1f}s\n")

# Step 4: Build a FAISS L2 similarity index for the passage embeddings
dim = passage_embeddings.shape[1]
print("[4/6] Building FAISS index...")
index = faiss.IndexFlatL2(dim)
index.add(passage_embeddings)
print(f"[4/6] Indexed {index.ntotal} vectors.\n")

# Step 5: Initialize the text generation model (GPT-2 Large)
print("[5/6] Loading generation pipeline...")
generator = pipeline(
    "text-generation",
    model="gpt2-large",
    tokenizer="gpt2-large",
    device=0  # CUDA:0
)
print("[5/6] Generator ready.\n")

# Format the generation prompt with retrieved context and structured instructions
def format_prompt(query, context):
    return (
        "You are Albert Einstein. Based on the following knowledge, answer the question thoughtfully and directly. "
        "Use clear, natural language. Write 2 or 3 complete sentences that stand alone. Do not refer to sources or background information.\n\n"
        + "\n---\n".join(context)
        + f"\n\nQuestion: {query}\nAnswer:"
    )

# Step 6: Define the RAG-based answer function using GPT-2 Large
def rag_advanced_answer(query, k=3):
    print(f"[6] Retrieving top {k} passages for query: {query!r}")
    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)
    ctx = [passages[i][:300] for i in I[0]]

    for rank, (dist, text) in enumerate(zip(D[0], ctx), 1):
        print(f"    {rank}. (dist={dist:.3f}) {text[:60]}…")

    prompt = format_prompt(query, ctx)
    output = generator(
        prompt,
        max_new_tokens=120,
        temperature=0.4,
        top_p=0.85,
        repetition_penalty=1.7,
        do_sample=True,
        pad_token_id=generator.tokenizer.eos_token_id,
        eos_token_id=generator.tokenizer.eos_token_id
    )[0]['generated_text']

    # Extract the answer text following "Answer:" and clean termination
    answer = output.split("Answer:")[-1].strip()
    for stop_token in ["\n\n", "\nQuestion:", "\nAnswer:", "---"]:
        if stop_token in answer:
            answer = answer.split(stop_token)[0].strip()
    if '.' in answer:
        answer = '.'.join(answer.split('.')[:-1]) + '.'
    print("[6] Generation complete.\n")
    return answer

# Example usage with predefined queries
queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the nature of light?"
]

for q in queries:
    print("=== QUERY ===")
    print(q)
    answer = rag_advanced_answer(q, k=3)
    print("=== ANSWER ===")
    print(answer)
    print("\n")
# Out:
# [1/6] Loading corpus from einstein_cleaned_final.txt...
# [1/6] Done. 3216 passages loaded.
#
# [2/6] Initializing SentenceTransformer embedder...
# [2/6] Embedder ready.
#
# [3/6] Computing embeddings in batches:
#     • Batch 1/51 done
#     • Batch 2/51 done
#     • Batch 3/51 done
#     • Batch 4/51 done
#     • Batch 5/51 done
#     • Batch 6/51 done
#     • Batch 7/51 done
#     • Batch 8/51 done
#     • Batch 9/51 done
#     • Batch 10/51 done
#     • Batch 11/51 done
#     • Batch 12/51 done
#     • Batch 13/51 done
#     • Batch 14/51 done
#     • Batch 15/51 done
#     • Batch 16/51 done
#     • Batch 17/51 done
#     • Batch 18/51 done
#     • Batch 19/51 done
#     • Batch 20/51 done
#     • Batch 21/51 done
#     • Batch 22/51 done
#     • Batch 23/51 done
#     • Batch 24/51 done
#     • Batch 25/51 done
#     • Batch 26/51 done
#     • Batch 27/51 done
#     • Batch 28/51 done
#     • Batch 29/51 done
#     • Batch 30/51 done
#     • Batch 31/51 done
#     • Batch 32/51 done
#     • Batch 33/51 done
#     • Batch 34/51 done
#     • Batch 35/51 done
#     • Batch 36/51 done
#     • Batch 37/51 done
#     • Batch 38/51 done
#     • Batch 39/51 done
#     • Batch 40/51 done
#     • Batch 41/51 done
#     • Batch 42/51 done
#     • Batch 43/51 done
#     • Batch 44/51 done
#     • Batch 45/51 done
#     • Batch 46/51 done
#     • Batch 47/51 done
#     • Batch 48/51 done
#     • Batch 49/51 done
#     • Batch 50/51 done
#     • Batch 51/51 done
# [3/6] Embeddings ready (shape=(3216, 384)) in 7.2s
#
# [4/6] Building FAISS index...
# [4/6] Indexed 3216 vectors.
#
# [5/6] Loading generation pipeline...
# Device set to use cuda:0
# [5/6] Generator ready.
#
# === QUERY ===
# What is the nature of time?
# [6] Retrieving top 3 passages for query: 'What is the nature of time?'
#     1. (dist=0.771) The time of an event taking place at a point P( x, y, z) is …
#     2. (dist=0.787) But thus withdrawn for long periods from the will-hardening …
#     3. (dist=0.858) It is hardly necessary to add, that anything which any insul…
# [6] Generation complete.
#
# === ANSWER ===
# It has been said before by many persons who have had some acquaintance with science; but I am unable now even to begin answering this important problem because my mind seems too full of other things than physics. (I think.) If you would like more detail about what we mean when we speak of "time," please read Chapter VI, Section V., page 434, where Professor Jevons gives us one such definition : Time consists simply of intervals between two successive occurrences ; they do not include interminable pauses during either interval.
#
#
# === QUERY ===
# How would you describe imagination?
# [6] Retrieving top 3 passages for query: 'How would you describe imagination?'
#     1. (dist=1.121) Il we ask ourselves how the structure of society and the cul…
#     2. (dist=1.162) For it to blossom there is needed, first of all, a certain d…
#     3. (dist=1.171) These no tion of such a setting rests exclusively on the fac…
# [6] Generation complete.
#
# === ANSWER ===
# Imagination has always been regarded with suspicion because its function seems so limited — what can one do when he cannot see anything? The most important thing about imagination however is that without being able to perceive any object whatsoever (which implies an absence), our mind makes up some imaginary picture from various elements existing around him. In other words, if I have seen something before my eyes, then I imagine myself seeing it again somewhere else.
#
#
# === QUERY ===
# What is the nature of light?
# [6] Retrieving top 3 passages for query: 'What is the nature of light?'
#     1. (dist=0.701) Light from the sun, seen through a spectroscope, gives a con…
#     2. (dist=0.715) What has surprised me most in your genera!attitude, ex? What…
#     3. (dist=0.845) In his treatise on light he wrote : If, in addition, light t…
# [6] Generation complete.
#
# === ANSWER ===
# It consists of two parts ; one part being visible (visible), another invisible. The first appears at night only because there was no atmosphere then capable of reflecting off such an object.

# %%
evaluate_model_metrics(rag_advanced_answer, model_name="RAG advanced", verbose=True)
# Out:
# [6] Retrieving top 3 passages for query: 'What is the nature of time?'
#     1. (dist=0.771) The time of an event taking place at a point P( x, y, z) is …
#     2. (dist=0.787) But thus withdrawn for long periods from the will-hardening …
#     3. (dist=0.858) It is hardly necessary to add, that anything which any insul…
# [6] Generation complete.
#
#
# [Query] What is the nature of time?
# [Response] Time has no definite character whatever; but there may exist some kind of relation between its duration (or periodicity), and certain other properties of things [which have been discussed above]. For example, we know by experience how much longer something takes than another thing when they both come into contact together — this relationship exists whether one comes first or second ; whereas nothing else could ever give us such evidence about what happens during different times.
#
# [6] Retrieving top 3 passages for query: 'How would you describe imagination?'
#     1. (dist=1.121) Il we ask ourselves how the structure of society and the cul…
#     2. (dist=1.162) For it to blossom there is needed, first of all, a certain d…
#     3. (dist=1.171) These no tion of such a setting rests exclusively on the fac…
# [6] Generation complete.
#
#
# [Query] How would you describe imagination?
# [Response] It consists essentially in an active process of creating ideas from experience with reference to objects existing outside our minds' field of vision. This activity can take place only when these imaginary images have been formed through some form of direct contact (i) With other people's imaginations, i.e., those who know what they imagine about others, ii.) Through sensory impressions derived either indirectly or consciously from one another, iii). From sensations arising out of physical events occurring within oneself : iv.). The latter two forms may occur simultaneously depending upon circumstances.
#
# [6] Retrieving top 3 passages for query: 'What is the nature of light?'
#     1. (dist=0.701) Light from the sun, seen through a spectroscope, gives a con…
#     2. (dist=0.715) What has surprised me most in your genera!attitude, ex? What…
#     3. (dist=0.845) In his treatise on light he wrote : If, in addition, light t…
# [6] Generation complete.
#
#
# [Query] What is the nature of light?
# [Response] The term "light" means any form of electromagnetic radiation with an intensity greater than 1/2 x 10 -7 Joules per square metre (J/m). It can be distinguished according to whether it consists entirely of photons emitted at right angles thereto, i.e., either one photon only, two rays separated by 180 degrees each, three pulses separated by 360°, four rays separated by 480 ° ; if they consist wholly of electrons passing between atoms simultaneously, then there must exist no other kind of emission but electronical.
#
#
# === Metrics for RAG advanced ===
# Tokens: 84.3333
# LexDiv: 0.9496
# Distinct-1: 0.9496
# Distinct-2: 0.9881
# AvgSentLen: 24.0417
# StyleSim: 0.2640
# QuerySim: 0.6069
# Repetition: 0.0187
# GenTime(s): 3.4030
# {'Tokens': 84.33333333333333,
#  'LexDiv': 0.9496464319993732,
#  'Distinct-1': 0.9496464319993732,
#  'Distinct-2': 0.9880952380952381,
#  'AvgSentLen': 24.041666666666668,
#  'StyleSim': 0.26398258407910663,
#  'QuerySim': 0.6069380442301432,
#  'Repetition': 0.018658392139770507,
#  'GenTime(s)': 3.403}

# %% [markdown]
# # MODEL 4: GPT-Neo 2.7B with RAG
#
# In this fourth model, we scale up significantly by replacing GPT-2 with GPT-Neo 2.7B—a powerful open-source language model developed by EleutherAI that brings a big jump in fluency and reasoning capacity. We also increase the number of retrieved passages and optimize the prompt-to-token flow for better long-form generation.
#
# 1) **Loading the Corpus**
# As before, we load our pre-cleaned corpus of Einstein passages from disk and store them as a list of paragraphs.
#
# 2) **Embedding with SentenceTransformer**
# We keep using `all-MiniLM-L6-v2` to embed each paragraph into 384-dimensional vectors. It's fast and effective for semantic similarity and works well with our retrieval setup.
#
# 3) **Indexing with FAISS**
# All embeddings are indexed using FAISS (`IndexFlatL2`), enabling fast L2-based nearest-neighbor search. Nothing changes here compared to earlier models.
#
# 4) **Loading GPT-Neo (2.7B)**
# Here’s the major upgrade: we move from GPT-2 Large (774M) to GPT-Neo 2.7B. This model has over 3 times more parameters and was trained on The Pile, making it significantly more capable for general knowledge reasoning and natural language generation. We load both the tokenizer and model using HuggingFace, and run them on GPU if available.
#
# 5) **Creating a Custom Generation Pipeline**
# We manually create the generation pipeline by loading the model and tokenizer, and ensure that both are sent to the correct device (GPU if present).
#
# 6) **RAG Answer Function (`rag_gptneo`)**
# We increase `k` to 7, retrieving more relevant context chunks per query. These are concatenated with section markers (`---`) and followed by a minimalistic prompt:
# `Question: ... Answer:`
# Unlike earlier models, there is no "Einstein persona" or stylistic guidance—GPT-Neo is expected to synthesize the context into a coherent answer on its own.
#
# 7) **Token Management and Truncation**
# We calculate the token length of the input prompt and truncate it if it exceeds the model’s token limit. We manually send the `input_ids` tensor to GPU to ensure the generation runs efficiently.
#
# 8) **Answer Extraction**
# We split the final output at the “Answer:” tag (if present), and return the cleaned answer as plain text.
#
# **Key Differences from Model 3:**
# - **Much larger model:** GPT-Neo 2.7B instead of GPT-2 Large → higher fluency and reasoning power.
# - **Manual token flow:** Explicit GPU handling and input truncation using tokenizer limits.
# - **No persona prompt:** More neutral style, letting the model generate based solely on retrieved knowledge.
# - **Higher context depth:** `k=7` passages retrieved instead of 3 for a richer information base.
#
# This model pushes the limits of our RAG setup in terms of scale, leveraging a high-capacity generator and feeding it more supporting context to produce deeper, more informative answers.

# %%
import os
import time
from sentence_transformers import SentenceTransformer
import faiss
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
import numpy as np

# Step 1: Load the preprocessed Einstein corpus
corpus_path = 'einstein_cleaned_final.txt'
print(f"[1/8] Loading corpus from {corpus_path}...")
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/8] Corpus loaded: {len(passages)} passages\n")

# Step 2: Initialize the SentenceTransformer embedder
print("[2/8] Initializing SentenceTransformer...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/8] Embedder ready\n")

# Step 3: Compute and index passage embeddings
print("[3/8] Computing embeddings and building FAISS index...")
batch_size = 64
emb_chunks = []
start = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    emb_chunks.append(embs)
    print(f"    [3/8] Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} completed")
passage_embeddings = np.vstack(emb_chunks)
dim = passage_embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(passage_embeddings)
print(f"[3/8] Embeddings indexed (shape={passage_embeddings.shape}) in {time.time()-start:.1f}s\n")

# Step 4: Load the GPT-Neo 2.7B model and tokenizer
print("[4/8] Initializing tokenizer and GPT-Neo model...")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-2.7B")
generator_model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-neo-2.7B")
device = 0 if torch.cuda.is_available() else -1
print(f"[4/8] Model and tokenizer loaded (device={'cuda' if device==0 else 'cpu'})\n")

# Step 5: Create the text-generation pipeline
print("[5/8] Building generation pipeline...")
generator = pipeline("text-generation", model=generator_model, tokenizer=tokenizer, device=device)
print("[5/8] Pipeline ready\n")

# Step 6–8: Define the full RAG inference process with GPT-Neo
def rag_gptneo(query, k=7, max_new_tokens=300, top_p=0.9):
    print(f"\n[6/8] Received query: {query!r}")

    # Step 6: Retrieve top-k semantically similar passages
    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)
    context = [passages[i] for i in I[0]]

    print(f"[6/8] Retrieved top-{k} passages:")
    for rank, (dist, text) in enumerate(zip(D[0], context), 1):
        print(f"    {rank}. (dist={dist:.3f}) {text[:60]}…")

    # Step 7: Prepare the prompt for generation
    context_text = "\n---\n".join(context)
    prompt = f"{context_text}\n\nQuestion: {query}\nAnswer:"

    # Ensure input fits within model's max input size
    max_input_tokens = tokenizer.model_max_length
    input_ids = tokenizer.encode(prompt, return_tensors="pt", truncation=True, max_length=max_input_tokens)
    input_ids = input_ids.to(generator_model.device)
    print(f"[7/8] Prompt ready (tokens={input_ids.shape[1]}/{max_input_tokens}, device={input_ids.device})")

    # Step 8: Generate the response
    output_ids = generator_model.generate(
        input_ids,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=top_p,
        pad_token_id=tokenizer.eos_token_id
    )
    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Extract the response portion following "Answer:"
    if "Answer:" in generated_text:
        answer = generated_text.split("Answer:")[-1].strip()
    else:
        answer = generated_text.strip()

    print("[8/8] Answer generated")
    return answer

# Example usage with predefined queries
example_queries = [
    "What is the nature of time?",
    "How would you describe imagination?"
]

for q in example_queries:
    print(f"\n=============================\nQuery: {q}")
    answer = rag_gptneo(q)
    print(f"\nAnswer:\n{answer}")
    print("=============================")
# Out:
# [1/8] Loading corpus from einstein_cleaned_final.txt...
# [1/8] Corpus loaded: 3216 passages
#
# [2/8] Initializing SentenceTransformer...
# [2/8] Embedder ready
#
# [3/8] Computing embeddings and building FAISS index...
#     [3/8] Batch 1/51 completed
#     [3/8] Batch 2/51 completed
#     [3/8] Batch 3/51 completed
#     [3/8] Batch 4/51 completed
#     [3/8] Batch 5/51 completed
#     [3/8] Batch 6/51 completed
#     [3/8] Batch 7/51 completed
#     [3/8] Batch 8/51 completed
#     [3/8] Batch 9/51 completed
#     [3/8] Batch 10/51 completed
#     [3/8] Batch 11/51 completed
#     [3/8] Batch 12/51 completed
#     [3/8] Batch 13/51 completed
#     [3/8] Batch 14/51 completed
#     [3/8] Batch 15/51 completed
#     [3/8] Batch 16/51 completed
#     [3/8] Batch 17/51 completed
#     [3/8] Batch 18/51 completed
#     [3/8] Batch 19/51 completed
#     [3/8] Batch 20/51 completed
#     [3/8] Batch 21/51 completed
#     [3/8] Batch 22/51 completed
#     [3/8] Batch 23/51 completed
#     [3/8] Batch 24/51 completed
#     [3/8] Batch 25/51 completed
#     [3/8] Batch 26/51 completed
#     [3/8] Batch 27/51 completed
#     [3/8] Batch 28/51 completed
#     [3/8] Batch 29/51 completed
#     [3/8] Batch 30/51 completed
#     [3/8] Batch 31/51 completed
#     [3/8] Batch 32/51 completed
#     [3/8] Batch 33/51 completed
#     [3/8] Batch 34/51 completed
#     [3/8] Batch 35/51 completed
#     [3/8] Batch 36/51 completed
#     [3/8] Batch 37/51 completed
#     [3/8] Batch 38/51 completed
#     [3/8] Batch 39/51 completed
#     [3/8] Batch 40/51 completed
#     [3/8] Batch 41/51 completed
#     [3/8] Batch 42/51 completed
#     [3/8] Batch 43/51 completed
#     [3/8] Batch 44/51 completed
#     [3/8] Batch 45/51 completed
#     [3/8] Batch 46/51 completed
#     [3/8] Batch 47/51 completed
#     [3/8] Batch 48/51 completed
#     [3/8] Batch 49/51 completed
#     [3/8] Batch 50/51 completed
#     [3/8] Batch 51/51 completed
# [3/8] Embeddings indexed (shape=(3216, 384)) in 6.9s
#
# [4/8] Initializing tokenizer and GPT-Neo model...
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# Device set to use cuda:0
# [4/8] Model and tokenizer loaded (device=cuda)
#
# [5/8] Building generation pipeline...
# [5/8] Pipeline ready
#
#
# =============================
# Query: What is the nature of time?
#
# [6/8] Received query: 'What is the nature of time?'
# [6/8] Retrieved top-7 passages:
#     1. (dist=0.771) The time of an event taking place at a point P( x, y, z) is …
#     2. (dist=0.787) But thus withdrawn for long periods from the will-hardening …
#     3. (dist=0.858) It is hardly necessary to add, that anything which any insul…
#     4. (dist=0.876) This brings us to the necessity for yet another gen- eraliza…
#     5. (dist=0.886) We might, of course, content ourselves with time values dete…
#     6. (dist=0.888) Every reference-body (coordinate system) has its own particu…
#     7. (dist=0.920) In order to free ourselves from this fatal error we shall sp…
# [7/8] Prompt ready (tokens=1041/2048, device=cuda:0)
# [8/8] Answer generated
#
# Answer:
# Time and space are not two attributes of the same thing but the same attribute in two different places. It was long ago pointed out by Maxwell that space and time are two different attributes of the same thing. Einstein demonstrated this by means of an experiment. Maxwell had discovered that light, travelling in a medium of uniform density, has a speed which depends upon the speed of the medium. Now if we have a gas, and move it with a uniform motion, we have a medium with the speed which depends upon the velocity of the gas. The experiment of Maxwell proved that there was no medium in the medium. Now in this experiment the two properties were shown to be different. But since a physical experiment has to be interpreted in terms of certain natural assumptions and not in terms of other assumptions, it is important that we keep clearly in our mind what we are trying to prove or disprove. The medium and the gas are parts of the same system and not separate systems. The gas is not in the air, therefore we are not in the air. The speed of the gas depends on the velocity of the medium in which it is moving and therefore on the density of the medium. This density does not depend upon the motion of the gas. The gas is in motion and therefore it is not in the air. Therefore the speed of the gas depends upon the density of the medium. The gas therefore has a constant velocity. And if a physical experiment is to be interpreted in terms of the natural assumptions which are
# =============================
#
# =============================
# Query: How would you describe imagination?
#
# [6/8] Received query: 'How would you describe imagination?'
# [6/8] Retrieved top-7 passages:
#     1. (dist=1.121) Il we ask ourselves how the structure of society and the cul…
#     2. (dist=1.162) For it to blossom there is needed, first of all, a certain d…
#     3. (dist=1.171) These no tion of such a setting rests exclusively on the fac…
#     4. (dist=1.174) This experience, which alone enables us to make inferences a…
#     5. (dist=1.177) To him Maxwell's equations in empty space held only far a pa…
#     6. (dist=1.182) On the possibility alone of such a correspondencerests the v…
#     7. (dist=1.183) When we try to subject our experiences of bodies by a comple…
# [7/8] Prompt ready (tokens=1069/2048, device=cuda:0)
# [8/8] Answer generated
#
# Answer:
# Imagination is a mental process which, as a result of a series of inter- action between sense-impressions, memory-pictures and conceptual forms, creates new forms of thought. Such forms of thought do not occur when we are merely in a physical condition, but they exist during our mental life as a result of the interplay between sense-impressions, memory-pictures and conceptual forms. The whole life of a man consists of these various mental processes, and the various mental processes only become possible as a result of the continuous inter- action of all of them. All of the mental processes, and not merely some of them, as when we merely receive impressions and forget them, and not only some of the processes, as when we imagine the past or the future, but all of them are inter- act. We can conceive of these mental processes occurring in an infinite number of ways, as follows: (1) a purely physical process, for example, the formation of a sensation by contact; (2) an interaction between a physical process and memory-pictures; (3) a interaction between a physical process and conceptual forms; and (4) a physical process and a mental process. The physical process itself can be considered as the result of an interaction between a physical process and memory-pictures. The physical process of formation of an impression does not necessarily begin as a result of the interaction of memory-pictures and physical processes. It can also result
# =============================

# %%
evaluate_model_metrics(rag_gptneo, model_name="GPT-NEO", verbose=True)
# Out:
# [6/8] Received query: 'What is the nature of time?'
# [6/8] Retrieved top-7 passages:
#     1. (dist=0.771) The time of an event taking place at a point P( x, y, z) is …
#     2. (dist=0.787) But thus withdrawn for long periods from the will-hardening …
#     3. (dist=0.858) It is hardly necessary to add, that anything which any insul…
#     4. (dist=0.876) This brings us to the necessity for yet another gen- eraliza…
#     5. (dist=0.886) We might, of course, content ourselves with time values dete…
#     6. (dist=0.888) Every reference-body (coordinate system) has its own particu…
#     7. (dist=0.920) In order to free ourselves from this fatal error we shall sp…
# [7/8] Prompt ready (tokens=1041/2048, device=cuda:0)
# [8/8] Answer generated
#
# [Query] What is the nature of time?
# [Response] Time in its turn is nature's way of making a living. But as to what we call time in the ordinary meaning of the word, the explanation is, that it is something we perceive, something we have to do with, something we call time. For this reason we have to go back to the question with which we began, and ask what we are doing when we are doing something, and how we are doing that when we are doing something.
#
# Time is the measure of what we can do and how we do it, of what we are and what we are doing.
#
# There is no time when we are not doing something.
#
# There is no time when we are not doing anything.
#
# There is no time at all.
#
# But to be able to do and to be doing something in the time we call the world is just as impossible as to be born without being a human being.
#
# Therefore we are never doing anything and are never doing anything at all.
#
# Therefore we cannot do anything and we cannot do anything at all.
#
# Therefore time has never been.
#
# But in order that time may exist it must be possible to measure the duration of something. And this we can do by means of clocks, by the help of clocks which will never run out, which will never be out of order, and therefore which can be regulated by their own clock, that is to say, by an absolute ruler. Now in order that
#
#
# [6/8] Received query: 'How would you describe imagination?'
# [6/8] Retrieved top-7 passages:
#     1. (dist=1.121) Il we ask ourselves how the structure of society and the cul…
#     2. (dist=1.162) For it to blossom there is needed, first of all, a certain d…
#     3. (dist=1.171) These no tion of such a setting rests exclusively on the fac…
#     4. (dist=1.174) This experience, which alone enables us to make inferences a…
#     5. (dist=1.177) To him Maxwell's equations in empty space held only far a pa…
#     6. (dist=1.182) On the possibility alone of such a correspondencerests the v…
#     7. (dist=1.183) When we try to subject our experiences of bodies by a comple…
# [7/8] Prompt ready (tokens=1069/2048, device=cuda:0)
# [8/8] Answer generated
#
# [Query] How would you describe imagination?
# [Response] It is nothing other than a set of associations and connections that have to do with the world. The world consists of matter, energy, space and time. Imagination is our mental response to this environment. To understand the way in which we are affected by the environment, and in what way we perceive this environment, we must consider the processes by which our minds make their way to and from the world. In these processes we have the concept of time and in the time we have the concept of space. This means that in the world there are different periods which are not simply distinct in our minds, but that these periods are different in the same way in which the days and nights are different, so that in time we have a concept of time, and in space we have a concept of space. We thus have the concept of the world. We have to understand this concept in order to understand the process by which our minds make their way to and from the world, and how in these processes we have the concept of time and in the time we have the concept of space.
# ---
# In the world there are various things, and each thing has a place and a function in the world. For example, man has a place in the world, and his place is man. The function of man in the world is that he knows. We cannot imagine man to exist without knowing that he exists, and we cannot imagine what he knows. We can only imagine a being with knowledge.
# ---
#
#
# [6/8] Received query: 'What is the nature of light?'
# [6/8] Retrieved top-7 passages:
#     1. (dist=0.701) Light from the sun, seen through a spectroscope, gives a con…
#     2. (dist=0.715) What has surprised me most in your genera!attitude, ex? What…
#     3. (dist=0.845) In his treatise on light he wrote : If, in addition, light t…
#     4. (dist=0.883) These experiments formed a strong support for the theory in …
#     5. (dist=0.914) THE WAVE THEORY OF LIGHT Let us recall why we broke off the …
#     6. (dist=0.915) It was only through the theory of general relativity that re…
#     7. (dist=0.922) They are somewhat like substance in the sense already explai…
# [7/8] Prompt ready (tokens=1022/2048, device=cuda:0)
# [8/8] Answer generated
#
# [Query] What is the nature of light?
# [Response] A wave is a mechanical thing in which we are not satisfied with the mechanical view of matter. If we consider the universe as a single gigantic wave-length we shall understand it in a better way. If we study the world through this giant wave-length we will be able to understand the world in a more scientific way. If we are dealing with the physical laws of the universe we are dealing with a gigantic wave-length, which we are not satisfied with the mechanical view of matter. We must admit that matter does not act according to the laws of mechanics; therefore a mechanical approach must be taken to physics. But if we admit that matter does not act according to the laws of mechanics, then we must admit that matter is also a wave. The fact that matter is a wave has been stated several times. When we see the world as a gigantic wave-length we shall understand it in a better way. If we study the world through this giant wave-length, we will be able to understand the world in a more scientific way. The world is a mechanical thing in which we are not satisfied with the mechanical view of matter. If we are dealing with the physical laws of the universe, then we are dealing with a gigantic wave-length. This wave-length is not a material wave; it is the universe. We should also admit that the universe has been constructed through a gigantic wave-length, which is
#
#
# === Metrics for GPT-NEO ===
# Tokens: 259.0000
# LexDiv: 0.3649
# Distinct-1: 0.3649
# Distinct-2: 0.6867
# AvgSentLen: 18.9579
# StyleSim: 0.3999
# QuerySim: 0.4470
# Repetition: 0.1859
# GenTime(s): 21.5477
# {'Tokens': 259.0,
#  'LexDiv': 0.36494042127921283,
#  'Distinct-1': 0.36494042127921283,
#  'Distinct-2': 0.6866901155821542,
#  'AvgSentLen': 18.957875457875456,
#  'StyleSim': 0.3998653292655945,
#  'QuerySim': 0.44700583815574646,
#  'Repetition': 0.18592458120330627,
#  'GenTime(s)': 21.547666666666668}

# %% [markdown]
# # MODEL 5: GPT-Neo 1.3B with Dynamic Context Truncation
#
# In this fifth model, we introduce a refined version of the GPT-Neo-based RAG pipeline. Instead of simply scaling the generator up, this version prioritizes *efficient use of the input token window* by dynamically adapting how much context to include for each query. We also adopt a more detailed, structured prompt to guide answer style and length.
#
# 1) **Corpus and Embedding (unchanged)**
# We reuse the same cleaned Einstein corpus and embed each paragraph using the `all-MiniLM-L6-v2` SentenceTransformer model. All embeddings are indexed using FAISS for fast nearest-neighbor search via L2 distance.
#
# 2) **Generator Upgrade: GPT-Neo 1.3B**
# We switch from GPT-Neo 2.7B to the lighter `gpt-neo-1.3B` model. While smaller, this version still provides high-quality outputs and is more manageable in environments with limited GPU memory (e.g., Colab).
#
# 3) **Smart Context Assembly**
# Instead of blindly retrieving `k=7` passages and concatenating all of them, we build the input **dynamically**, one paragraph at a time. After each addition, we test whether the resulting prompt (including the final question and instructions) still fits within the model’s token limit. This ensures we use *as much relevant context as possible* without truncation, which is especially important for long-generation models.
#
# 4) **Prompting Strategy**
# The prompt tells the model to act as Albert Einstein and provide a clear, thoughtful, and concise answer based on the retrieved "excerpts." It explicitly instructs the model *not to mention the excerpts*, which helps avoid meta comments. The target answer length is 3–5 sentences.
#
# 5) **Generation Details**
# We sample up to 400 new tokens using `top_p` sampling with moderate temperature, and apply a `no_repeat_ngram_size` of 3 to prevent redundant phrasing.
#
# 6) **Post-processing**
# We extract the answer from the generated output after the “Answer:” token, clean it up, and trim trailing content after known markers (like “---” or repeated prompt sections). We also ensure the answer ends with a full stop and makes grammatical sense.
#
# **Key Differences from Model 4:**
# - **Smaller model (1.3B vs 2.7B)**, better for memory-constrained environments.
# - **Dynamic context selection** ensures optimal use of token budget with no waste or hard truncation.
# - **Stronger prompt structure** guides both tone and content.
# - **Improved repetition control** using `no_repeat_ngram_size`.
#
# This model finds a sweet spot between resource efficiency and generation quality. Thanks to smarter context management and focused prompting, it often produces answers that are just as good—if not better—than its larger predecessor.

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import time
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Step 1: Load the cleaned corpus
print("[1/8] Loading corpus...")
corpus_path = 'einstein_cleaned_final.txt'
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/8] Corpus loaded: {len(passages)} passages\n")

# Step 2: Initialize the SentenceTransformer embedder
print("[2/8] Initializing SentenceTransformer...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/8] Embedder ready\n")

# Step 3: Compute passage embeddings and build FAISS index
print("[3/8] Computing embeddings and indexing...")
batch_size = 64
emb_chunks = []
start = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    emb_chunks.append(embs)
    print(f"    [3/8] Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} completed")
passage_embeddings = np.vstack(emb_chunks)
dim = passage_embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(passage_embeddings)
print(f"[3/8] Indexed {passage_embeddings.shape[0]} vectors in {time.time()-start:.1f}s\n")

# Step 4: Load the GPT-Neo 1.3B model and tokenizer
print("[4/8] Initializing tokenizer and GPT-Neo (1.3B)...")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")
generator_model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator_model.to(device)
print(f"[4/8] Model and tokenizer ready (device={device})\n")

# Step 5–7: Define the RAG pipeline using GPT-Neo 1.3B
def rag_gptneo_2(query, k=7, max_new_tokens=400, top_p=0.8, temperature=0.7):
    print(f"\n[5/8] Processing query: {query!r}")

    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)

    total_tokens = 0
    context_chunks = []

    # Dynamically accumulate context passages until input length limit
    for idx in I[0]:
        para_text = passages[idx][:1500]
        test_prompt = (
            f"You are Albert Einstein. Based on the following excerpts, answer the question in your own words. "
            "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
            "Do not refer to the excerpts or sources. Just answer directly.\n\n"
            "Excerpts:\n" + "\n---\n".join(context_chunks + [para_text]) + f"\n\nQuestion: {query}\nAnswer:"
        )
        token_count = len(tokenizer.encode(test_prompt))

        if token_count < tokenizer.model_max_length - max_new_tokens:
            context_chunks.append(para_text)
            total_tokens = token_count
        else:
            break

    print(f"[5/8] Collected {len(context_chunks)} context passages (approx. {total_tokens} tokens)\n")

    context_text = "\n---\n".join(context_chunks)
    prompt = (
        f"You are Albert Einstein. Based on the following excerpts, answer the question in your own words. "
        "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
        "Do not refer to the excerpts or sources. Just answer directly.\n\n"
        "Excerpts:\n" + context_text + f"\n\nQuestion: {query}\nAnswer:"
    )

    max_input_tokens = tokenizer.model_max_length
    input_ids = tokenizer.encode(prompt, return_tensors="pt", truncation=True, max_length=max_input_tokens).to(device)
    print(f"[6/8] Prompt ready (tokens={input_ids.shape[1]}/{max_input_tokens})")

    output_ids = generator_model.generate(
        input_ids,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=top_p,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3
    )

    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Extract only the answer portion
    if "Answer:" in generated_text:
        answer = generated_text.split("Answer:")[-1].strip()
    else:
        answer = generated_text.strip()

    for stop_token in ["---", "\n\n", "\nAnswer:"]:
        if stop_token in answer:
            answer = answer.split(stop_token)[0].strip()
    if '.' in answer:
        answer = '.'.join(answer.split('.')[:-1]) + '.'

    print("[7/8] Answer generated")
    return answer

# Step 8: Run example queries
example_queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the nature of light?"
]

for q in example_queries:
    print(f"\n=============================\nQuery: {q}")
    answer = rag_gptneo_2(q)
    print(f"\nAnswer:\n{answer}")
    print("=============================")
# Out:
# [1/8] Loading corpus...
# [1/8] Corpus loaded: 3216 passages
#
# [2/8] Initializing SentenceTransformer...
# [2/8] Embedder ready
#
# [3/8] Computing embeddings and indexing...
#     [3/8] Batch 1/51 completed
#     [3/8] Batch 2/51 completed
#     [3/8] Batch 3/51 completed
#     [3/8] Batch 4/51 completed
#     [3/8] Batch 5/51 completed
#     [3/8] Batch 6/51 completed
#     [3/8] Batch 7/51 completed
#     [3/8] Batch 8/51 completed
#     [3/8] Batch 9/51 completed
#     [3/8] Batch 10/51 completed
#     [3/8] Batch 11/51 completed
#     [3/8] Batch 12/51 completed
#     [3/8] Batch 13/51 completed
#     [3/8] Batch 14/51 completed
#     [3/8] Batch 15/51 completed
#     [3/8] Batch 16/51 completed
#     [3/8] Batch 17/51 completed
#     [3/8] Batch 18/51 completed
#     [3/8] Batch 19/51 completed
#     [3/8] Batch 20/51 completed
#     [3/8] Batch 21/51 completed
#     [3/8] Batch 22/51 completed
#     [3/8] Batch 23/51 completed
#     [3/8] Batch 24/51 completed
#     [3/8] Batch 25/51 completed
#     [3/8] Batch 26/51 completed
#     [3/8] Batch 27/51 completed
#     [3/8] Batch 28/51 completed
#     [3/8] Batch 29/51 completed
#     [3/8] Batch 30/51 completed
#     [3/8] Batch 31/51 completed
#     [3/8] Batch 32/51 completed
#     [3/8] Batch 33/51 completed
#     [3/8] Batch 34/51 completed
#     [3/8] Batch 35/51 completed
#     [3/8] Batch 36/51 completed
#     [3/8] Batch 37/51 completed
#     [3/8] Batch 38/51 completed
#     [3/8] Batch 39/51 completed
#     [3/8] Batch 40/51 completed
#     [3/8] Batch 41/51 completed
#     [3/8] Batch 42/51 completed
#     [3/8] Batch 43/51 completed
#     [3/8] Batch 44/51 completed
#     [3/8] Batch 45/51 completed
#     [3/8] Batch 46/51 completed
#     [3/8] Batch 47/51 completed
#     [3/8] Batch 48/51 completed
#     [3/8] Batch 49/51 completed
#     [3/8] Batch 50/51 completed
#     [3/8] Batch 51/51 completed
# [3/8] Indexed 3216 vectors in 6.3s
#
# [4/8] Initializing tokenizer and GPT-Neo (1.3B)...
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# [4/8] Model and tokenizer ready (device=cuda)
#
#
# =============================
# Query: What is the nature of time?
#
# [5/8] Processing query: 'What is the nature of time?'
# [5/8] Collected 7 context passages (approx. 1096 tokens)
#
# [6/8] Prompt ready (tokens=1096/2048)
# [7/8] Answer generated
#
# Answer:
# Time is a measure of the passage of events in time. A clock gives a definite time when the hands are put together, and this time is the time for which the clock is adjusted. The clock is a device which records the passage in time of the events which it records.
# =============================
#
# =============================
# Query: How would you describe imagination?
#
# [5/8] Processing query: 'How would you describe imagination?'
# [5/8] Collected 7 context passages (approx. 1124 tokens)
#
# [6/8] Prompt ready (tokens=1124/2048)
# [7/8] Answer generated
#
# Answer:
# Imagination, for me, means the mental activity of the imagination, which is a sort of "fancy-work" of the mind.
# Question 2: What is the meaning of the expression "the world-picture"?
# Answer 2: The world-picture is the picture of the world in the mind of the person who has created it. It is a picture of a reality which is not a real reality, but a "real" picture of an unreal reality. It can be compared to the picture in a mirror, which can be looked at, but not seen.
# Answer 3: The picture is an "ideal" picture. It has the same status as a picture in the mirror.
# Explanation:
# 1. The world picture is the world picture of your imagination.
# 2. The "world-picture" is the "idea" of a picture.
# 3. The picture of "the real world" is a "fantasy.
# =============================
#
# =============================
# Query: What is the nature of light?
#
# [5/8] Processing query: 'What is the nature of light?'
# [5/8] Collected 7 context passages (approx. 1077 tokens)
#
# [6/8] Prompt ready (tokens=1077/2048)
# [7/8] Answer generated
#
# Answer:
# Light is a wave of energy which, by the way, is the only thing that is not an elementary particle. Light, like the rest of matter, consists of a continuous wave-pattern of energy.
# =============================

# %%
evaluate_model_metrics(rag_gptneo_2, model_name="GPT-NEO 2", verbose=True)
# Out:
# [5/8] Processing query: 'What is the nature of time?'
# [5/8] Collected 7 context passages (approx. 1096 tokens)
#
# [6/8] Prompt ready (tokens=1096/2048)
# [7/8] Answer generated
#
# [Query] What is the nature of time?
# [Response] Time is a quantity of motion.
#
#
# [5/8] Processing query: 'How would you describe imagination?'
# [5/8] Collected 7 context passages (approx. 1124 tokens)
#
# [6/8] Prompt ready (tokens=1124/2048)
# [7/8] Answer generated
#
# [Query] How would you describe imagination?
# [Response] It is the power of producing, through the use of the imagination, an image of the real external world. Imaginary images, in particular, are the result, in accordance with the principle of relativity, of the propagation of light, and in accordance also with the law of reflection, of an image which is the image of a light ray. The image is not a real thing, but is the result (as it were) of a certain state of consciousness, of what is called the "image-process." This image-process is a process of the mind, in which the real world is imagined, but which is not the real thing itself.
# The power of imagination is not, therefore, the power to produce a real object, but the power, in addition, to create images, which are not real, but are the images of a real world.
# This power is called "imagination" because it is the imagination of a reality, and not the power which creates reality.
# For example, the mind of man imagines a world of objects which are really there, but it does not produce them, because it does it only by means, not of the power that creates reality, but only of the imagi- nation.
# " Imagination" is the term applied to the power in man which is capable of producing an image in the mind.
# To say that it is not "imaginary" is not to say that the power is not in man. The power is in man, but not in the way it is in the real objects.
# In the real object the power and the imagina- tion are in the form and manner of the relation between the object and the mind which is in that object.
# There is no real object in the world, but there are objects which exist only in the imagination.
# It is the same with the power.
#
#
# [5/8] Processing query: 'What is the relationship between gravity and acceleration?'
# [5/8] Collected 7 context passages (approx. 1090 tokens)
#
# [6/8] Prompt ready (tokens=1090/2048)
# [7/8] Answer generated
#
# [Query] What is the relationship between gravity and acceleration?
# [Response] Gravity is the force that causes the movement. Acceleration is the effect of gravity.
# Question 2: How can we determine the magnitude of the acceleration? The acceleration is the product of the velocity and the mass of the particle.
# Answer 2: If the velocity of the moving particle is known, the mass can be found from the acceleration.
# (3) The relation between acceleration and gravitational field is as follows:
# A.
# The gravitational field due to a body at rest is the sum of the field due the body at the point of observation and the field of the surrounding space.
# B.
# In the case of a moving body the field is the same as that of a stationary body.
# C.
# If the body is at rest, the field has no acceleration. If the body moves, the gravitational force acts on the body in the same way as the force due to the surrounding field.
# D.
# For a body moving with a constant velocity, the force is the acceleration due to gravity. For a body accelerating with a decreasing velocity, it is the decreasing force.
# E.
# A body moving at a constant speed, the velocity is the square of the distance from the body to the point where it is observed. The force is therefore the acceleration (or force) due to gravitation.
# F.
# It is possible to determine the force without using the acceleration, by the formula:
# F = a x
# (4) This is the formula which is used to calculate the gravitational acceleration of the earth.
# G.
# We can determine the gravitational constant from the formula :
# G = c/a
# (5) The constant c is the velocity in meters per second.
# H.
# Since the gravitational potential is constant, the potential energy is the work done by gravity. The work done is the energy which is released by the gravitational attraction.
# I.
#
#
# [5/8] Processing query: 'How does mass affect space-time?'
# [5/8] Collected 7 context passages (approx. 1102 tokens)
#
# [6/8] Prompt ready (tokens=1102/2048)
# [7/8] Answer generated
#
# [Query] How does mass affect space-time?
# [Response] Mass is a property of space-times. It is a measure of the space that is occupied by the matter that has a certain density.
#
#
# === Metrics for GPT-NEO 2 ===
# Tokens: 163.2500
# LexDiv: 0.6253
# Distinct-1: 0.6253
# Distinct-2: 0.8820
# AvgSentLen: 13.6292
# StyleSim: 0.3248
# QuerySim: 0.6165
# Repetition: 0.1771
# GenTime(s): 16.5798
# {'Tokens': 163.25,
#  'LexDiv': 0.6253297881111386,
#  'Distinct-1': 0.6253297881111386,
#  'Distinct-2': 0.8820409212466684,
#  'AvgSentLen': 13.62923076923077,
#  'StyleSim': 0.32480979710817337,
#  'QuerySim': 0.6165294051170349,
#  'Repetition': 0.1771409079683463,
#  'GenTime(s)': 16.57975}

# %% [markdown]
# # MODEL 6: Flan-T5 Small with Cosine Nearest Neighbors
#
# In this sixth model, we shift from autoregressive generators like GPT-2 and GPT-Neo to a **sequence-to-sequence model**, specifically `Flan-T5 Small` by Google. This model is instruction-tuned out of the box, making it especially well-suited for prompt-based tasks like question answering and paraphrasing. We also replace FAISS with a simpler cosine similarity index using `scikit-learn`.
#
# 1) **Loading the Corpus**
# We load the cleaned corpus of Einstein passages into a list, as in all previous models.
#
# 2) **Embedding the Passages**
# We use the same lightweight SentenceTransformer (`all-MiniLM-L6-v2`) to embed each passage into a 384-dimensional vector. These embeddings serve as the basis for semantic retrieval.
#
# 3) **Retrieval with Cosine Similarity**
# Instead of using FAISS, we use `scikit-learn`’s `NearestNeighbors` with `metric='cosine'`. This is easier to set up and interpretable, and works well when dealing with a few thousand vectors. We retrieve the top `k=5` passages closest to the query embedding.
#
# 4) **Switching to Flan-T5**
# We use `google/flan-t5-small`, a small but instruction-finetuned T5 model that’s capable of following natural language prompts. Unlike GPT-based models, Flan-T5 takes an input string and generates an output string in a fully encoder-decoder architecture.
#
# 5) **Prompt Design**
# We use a new prompt format tailored to T5-style models:
# “You are Albert Einstein. Based on the following excerpts, answer the question in first person, using your own words.”
# The retrieved context is appended under “Excerpts:”, followed by the question. This style plays to Flan-T5’s strengths—concise, factual, instruction-following answers.
#
# 6) **Controlled Generation**
# We use nucleus sampling (`top_p=0.9`) with moderate temperature (`0.7`) to allow creativity while maintaining relevance. The `min_length` and `max_length` parameters help ensure that the answer is reasonably detailed and doesn’t terminate too early.
#
# 7) **Answer Extraction**
# The generated output is split on “Answer:” to isolate the response cleanly, which is then printed and returned.
#
# **Key Differences from Previous Models:**
# - **Different model architecture:** Flan-T5 is encoder-decoder, not autoregressive.
# - **Instruction tuning:** Flan-T5 was pretrained with supervised tasks and follows prompts better out of the box.
# - **Simplified retriever:** NearestNeighbors with cosine distance replaces FAISS.
# - **Different output style:** More focused, structured, and generally shorter answers, often with a clearer logical flow.
#
# This model trades raw generative power for interpretability and prompt-following ability, making it ideal for concise, structured Einstein-like answers grounded in retrieved content.

# %%
import os
import time
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import NearestNeighbors
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# Step 1: Load the cleaned corpus
CLEANED_PATH = 'einstein_cleaned_final.txt'
EMBED_MODEL = 'all-MiniLM-L6-v2'
GEN_MODEL = 'google/flan-t5-small'
K = 5

with open(CLEANED_PATH, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1] Loaded {len(passages)} passages.")

# Step 2: Embed the passages using a SentenceTransformer
embedder = SentenceTransformer(EMBED_MODEL)
print("[2] Computing embeddings...")
embeddings = embedder.encode(passages, convert_to_numpy=True, show_progress_bar=True)

# Step 3: Build a Nearest Neighbors index using cosine similarity
nn = NearestNeighbors(n_neighbors=K, metric='cosine')
nn.fit(embeddings)
print("[3] NearestNeighbors index ready.")

# Step 4: Load Flan-T5 model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(GEN_MODEL)
model = AutoModelForSeq2SeqLM.from_pretrained(GEN_MODEL)
generator = pipeline(
    "text2text-generation",
    model=model,
    tokenizer=tokenizer,
    device=-1,  # CPU (set to 0 for CUDA if available)
)

# Step 5: Define the RAG answer generation function
def rag_flan_t5(query, k=K, max_length=500, min_length=150, top_p=0.9, temperature=0.7):
    t0 = time.time()
    print(f"\n[RAG-FLAN] Query: {query}")

    # Retrieve top-k relevant passages based on cosine similarity
    q_emb = embedder.encode([query], convert_to_numpy=True)
    dists, idxs = nn.kneighbors(q_emb, n_neighbors=k)
    retrieved = [passages[i] for i in idxs[0]]
    print(f"[RAG-FLAN] Retrieved passages (cosine distances): {dists[0].round(3).tolist()}")

    # Compose the prompt for conditional generation
    context_text = "\n---\n".join(retrieved)
    prompt = (
        "You are Albert Einstein. Based on the following excerpts, answer the question in first person, using your own words.\n\n"
        "Excerpts:\n" + context_text +
        f"\n\nQuestion: {query}\nAnswer:"
    )

    # Generate the answer using the T5 model
    out = generator(
        prompt,
        max_length=max_length,
        min_length=min_length,
        do_sample=True,
        top_p=top_p,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id
    )[0]["generated_text"]

    # Extract and clean the answer
    answer = out.split("Answer:")[-1].strip()

    print("\n=== EINSTEIN'S ANSWER ===")
    print(answer)
    print(f"[RAG-FLAN] Done in {time.time() - t0:.2f}s\n")

    return answer

# Step 6: Run the model if executed as main
if __name__ == "__main__":
    query = "What is the nature of time?"
    rag_flan_t5(query)
# Out:
# [1] Loaded 3216 passages.
# [2] Computing embeddings...
# Batches:   0%|          | 0/101 [00:00<?, ?it/s]
# [3] NearestNeighbors index ready.
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Device set to use cpu
# Token indices sequence length is longer than the specified maximum sequence length for this model (901 > 512). Running this sequence through the model will result in indexing errors
# [RAG-FLAN] Query: What is the nature of time?
# [RAG-FLAN] Retrieved passages (cosine distances): [0.38600000739097595, 0.3930000066757202, 0.42899999022483826, 0.43799999356269836, 0.4429999887943268]
#
# === EINSTEIN'S ANSWER ===
# physical description of natural processes. --- Is it immaterial what kind of processes one chooses for such a definition of time. -- Is it immaterial what kind of processes one chooses for such a definition of time? -- Is it immaterial what kind of processes one chooses for such a definition of time. -- Is it immaterial what kind of processes one chooses for such a definition of time. -- Is it immaterial what kind of processes one chooses for such a definition of time? -- Is it immaterial what kind of processes one chooses for such a definition of time. -- Is it immaterial what kind of processes one chooses for such a definition of time. --
# [RAG-FLAN] Done in 6.50s

# %%
evaluate_model_metrics(rag_flan_t5, model_name="FLAN 5", verbose=True)
# Out:
# [RAG-FLAN] Query: What is the nature of time?
# [RAG-FLAN] Retrieved passages (cosine distances): [0.38600000739097595, 0.3930000066757202, 0.42899999022483826, 0.43799999356269836, 0.4429999887943268]
#
# === EINSTEIN'S ANSWER ===
# The time is at all events independent of the position of the system of co-ordinates in our space of reference. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time.
# [RAG-FLAN] Done in 7.38s
#
#
# [Query] What is the nature of time?
# [Response] The time is at all events independent of the position of the system of co-ordinates in our space of reference. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time. It is immaterial what kind of processes one chooses for such a definition of time.
#
#
# [RAG-FLAN] Query: How would you describe imagination?
# [RAG-FLAN] Retrieved passages (cosine distances): [0.5609999895095825, 0.5809999704360962, 0.5849999785423279, 0.5870000123977661, 0.5879999995231628]
#
# === EINSTEIN'S ANSWER ===
# more important than knowledge. --- In physics takes the form of experiment and measurement. --- To him who is a discoverer in this field the products of his imagination appear so necessary and natural that he regards them, and would like to have them regarded by others, not as creations of thought but as given realities. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement.
# [RAG-FLAN] Done in 6.55s
#
#
# [Query] How would you describe imagination?
# [Response] more important than knowledge. --- In physics takes the form of experiment and measurement. --- To him who is a discoverer in this field the products of his imagination appear so necessary and natural that he regards them, and would like to have them regarded by others, not as creations of thought but as given realities. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement. --- In physics takes the form of experiment and measurement.
#
#
# [RAG-FLAN] Query: What is the relationship between gravity and acceleration?
# [RAG-FLAN] Retrieved passages (cosine distances): [0.4830000102519989, 0.48399999737739563, 0.5350000262260437, 0.5360000133514404, 0.5460000038146973]
#
# === EINSTEIN'S ANSWER ===
# the force of gravity if there is to be equilibrium. --- The introduction of co-ordinate systems accelerated relatively to each other as equally legitimate systems, such as they appear conditioned by the identity of inertia and weight, leads, in conjunction with the re- sults of the special theory of relativity, to the conclu- sion that the laws governing the occupation of space by solid bodies, when gravitational fields are present, do not correspond to the laws of Euclidean geometry. --- The introduction of co-ordinate systems accelerated relatively to inertial systems involves the appearance of gravitational fields relative to the latter. --- The introduction of co-ordinate systems accelerated relatively to inertial systems involves the appearance of gravitational fields relative to the latter.
# [RAG-FLAN] Done in 6.35s
#
#
# [Query] What is the relationship between gravity and acceleration?
# [Response] the force of gravity if there is to be equilibrium. --- The introduction of co-ordinate systems accelerated relatively to each other as equally legitimate systems, such as they appear conditioned by the identity of inertia and weight, leads, in conjunction with the re- sults of the special theory of relativity, to the conclu- sion that the laws governing the occupation of space by solid bodies, when gravitational fields are present, do not correspond to the laws of Euclidean geometry. --- The introduction of co-ordinate systems accelerated relatively to inertial systems involves the appearance of gravitational fields relative to the latter. --- The introduction of co-ordinate systems accelerated relatively to inertial systems involves the appearance of gravitational fields relative to the latter.
#
#
# [RAG-FLAN] Query: How does mass affect space-time?
# [RAG-FLAN] Retrieved passages (cosine distances): [0.4819999933242798, 0.5070000290870667, 0.5130000114440918, 0.527999997138977, 0.531000018119812]
#
# === EINSTEIN'S ANSWER ===
# qf energy content. --- The special properties of space and time in any region are defined by these r/s which are themselves determined, by the actual distribution of matter in the locality. --- The special relativity theory achieved therr logical reconciliation by making a change in kinematics, that is to say, in the doctrine of the physical laws of space and time. According to the theory of relativity, action at a distance with the velocity of light always takes the place of instantaneous action at a distance or of action at a distance with an infinite velocity of transmission. According to the theory of relativity, there is no essential distinction between mass and energy.
# [RAG-FLAN] Done in 6.46s
#
#
# [Query] How does mass affect space-time?
# [Response] qf energy content. --- The special properties of space and time in any region are defined by these r/s which are themselves determined, by the actual distribution of matter in the locality. --- The special relativity theory achieved therr logical reconciliation by making a change in kinematics, that is to say, in the doctrine of the physical laws of space and time. According to the theory of relativity, action at a distance with the velocity of light always takes the place of instantaneous action at a distance or of action at a distance with an infinite velocity of transmission. According to the theory of relativity, there is no essential distinction between mass and energy.
#
#
# === Metrics for FLAN 5 ===
# Tokens: 129.0000
# LexDiv: 0.4258
# Distinct-1: 0.4258
# Distinct-2: 0.5607
# AvgSentLen: 20.2875
# StyleSim: 0.4388
# QuerySim: 0.4218
# Repetition: 0.5274
# GenTime(s): 6.6842
# {'Tokens': 129.0,
#  'LexDiv': 0.4258038402235037,
#  'Distinct-1': 0.4258038402235037,
#  'Distinct-2': 0.560705129678581,
#  'AvgSentLen': 20.2875,
#  'StyleSim': 0.43877312541007996,
#  'QuerySim': 0.42176366224884987,
#  'Repetition': 0.5273632788008932,
#  'GenTime(s)': 6.68425}
